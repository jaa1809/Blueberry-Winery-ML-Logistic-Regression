# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches  # Import mpatches for custom legends
import seaborn as sns
from scipy import stats

# %%
#Get some info
red_wine = pd.read_csv('/Users/jaamann/Documents/Vs Code Python /Code Academy/Exercises/Module 2/Sprint 1/wine+quality/winequality-red.csv', sep = ';')
white_wine = pd.read_csv('/Users/jaamann/Documents/Vs Code Python /Code Academy/Exercises/Module 2/Sprint 1/wine+quality/winequality-white.csv', sep = ';')
all_wines = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

all_wines.head()
#white_wine.head(10)
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# std       0.047065           10.460157            32.895324     0.001887
# min       0.012000            1.000000             6.000000     0.990070
# 25%       0.070000            7.000000            22.000000     0.995600
#
#                                  ... White Wines Stats                 \
#                 pH    sulphates  ...       citric acid residual sugar
# count  1599.000000  1599.000000  ...       4898.000000    4898.000000
# mean      3.311113     0.658149  ...          0.334192       6.391415
# std       0.154386     0.169507  ...          0.121020       5.072058
# min       2.740000     0.330000  ...          0.000000       0.600000
# 25%       3.210000     0.550000  ...          0.270000       1.700000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  4898.000000         4898.000000          4898.000000  4898.000000
# mean      0.045772           35.308085           138.360657     0.994027
# std       0.021848           17.007137            42.498065     0.002991
# min       0.009000            2.000000             9.000000     0.987110
# 25%       0.036000           23.000000           108.000000     0.991723
#
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
#
# [5 rows x 24 columns]

# %%
all_wines.dtypes
# Out:
# Red Wines Stats    fixed acidity           float64
#                    volatile acidity        float64
#                    citric acid             float64
#                    residual sugar          float64
#                    chlorides               float64
#                    free sulfur dioxide     float64
#                    total sulfur dioxide    float64
#                    density                 float64
#                    pH                      float64
#                    sulphates               float64
#                    alcohol                 float64
#                    quality                 float64
# White Wines Stats  fixed acidity           float64
#                    volatile acidity        float64
#                    citric acid             float64
#                    residual sugar          float64
#                    chlorides               float64
#                    free sulfur dioxide     float64
#                    total sulfur dioxide    float64
#                    density                 float64
#                    pH                      float64
#                    sulphates               float64
#                    alcohol                 float64
#                    quality                 float64
# dtype: object

# %%
all_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Red Wines Stats, fixed acidity)           8 non-null      float64
#  1   (Red Wines Stats, volatile acidity)        8 non-null      float64
#  2   (Red Wines Stats, citric acid)             8 non-null      float64
#  3   (Red Wines Stats, residual sugar)          8 non-null      float64
#  4   (Red Wines Stats, chlorides)               8 non-null      float64
#  5   (Red Wines Stats, free sulfur dioxide)     8 non-null      float64
#  6   (Red Wines Stats, total sulfur dioxide)    8 non-null      float64
#  7   (Red Wines Stats, density)                 8 non-null      float64
#  8   (Red Wines Stats, pH)                      8 non-null      float64
#  9   (Red Wines Stats, sulphates)               8 non-null      float64
#  10  (Red Wines Stats, alcohol)                 8 non-null      float64
#  11  (Red Wines Stats, quality)                 8 non-null      float64
#  12  (White Wines Stats, fixed acidity)         8 non-null      float64
#  13  (White Wines Stats, volatile acidity)      8 non-null      float64
#  14  (White Wines Stats, citric acid)           8 non-null      float64
#  15  (White Wines Stats, residual sugar)        8 non-null      float64
#  16  (White Wines Stats, chlorides)             8 non-null      float64
#  17  (White Wines Stats, free sulfur dioxide)   8 non-null      float64
#  18  (White Wines Stats, total sulfur dioxide)  8 non-null      float64
#  19  (White Wines Stats, density)               8 non-null      float64
#  20  (White Wines Stats, pH)                    8 non-null      float64
#  21  (White Wines Stats, sulphates)             8 non-null      float64
#  22  (White Wines Stats, alcohol)               8 non-null      float64
#  23  (White Wines Stats, quality)               8 non-null      float64
# dtypes: float64(24)
# memory usage: 1.6+ KB

# %%
all_wines.describe().T
# Out:
#                                         count        mean          std  \
# Red Wines Stats   fixed acidity           8.0  206.720092   562.580675
#                   volatile acidity        8.0  200.369610   565.132198
#                   citric acid             8.0  200.154472   565.219030
#                   residual sugar          8.0  203.256092   563.985992
#                   chlorides               8.0  199.999566   565.281572
#                   free sulfur dioxide     8.0  217.541885   558.625565
#                   total sulfur dioxide    8.0  261.920390   547.794674
#                   density                 8.0  200.622822   565.029813
#                   pH                      8.0  202.391937   564.316075
#                   sulphates               8.0  200.507207   565.076691
#                   alcohol                 8.0  208.073581   562.032526
#                   quality                 8.0  204.180449   563.596382
# White Wines Stats fixed acidity           8.0  618.012332  1729.380280
#                   volatile acidity        8.0  612.543629  1731.585893
#                   citric acid             8.0  612.636901  1731.548251
#                   residual sugar          8.0  624.082934  1727.057466
#                   chlorides               8.0  612.318953  1731.676650
#                   free sulfur dioxide     8.0  668.039403  1711.684749
#                   total sulfur dioxide    8.0  742.107340  1684.244524
#                   density                 8.0  613.000584  1731.401261
#                   pH                      8.0  614.678658  1730.723539
#                   sulphates               8.0  612.666747  1731.536140
#                   alcohol                 8.0  620.405611  1728.413190
#                   quality                 8.0  616.720443  1729.899811
#
#                                              min        25%         50%  \
# Red Wines Stats   fixed acidity         1.741096   6.475000    8.109819
#                   volatile acidity      0.120000   0.337265    0.523910
#                   citric acid           0.000000   0.168601    0.265488
#                   residual sugar        0.900000   1.777482    2.369403
#                   chlorides             0.012000   0.064266    0.083233
#                   free sulfur dioxide   1.000000   9.595118   14.937461
#                   total sulfur dioxide  6.000000  30.171493   42.233896
#                   density               0.001887   0.994217    0.996748
#                   pH                    0.154386   3.092500    3.310557
#                   sulphates             0.169507   0.495000    0.639074
#                   alcohol               1.065668   9.225000   10.311492
#                   quality               0.807569   4.500000    5.818011
# White Wines Stats fixed acidity         0.843868   5.675000    6.827394
#                   volatile acidity      0.080000   0.182699    0.269121
#                   citric acid           0.000000   0.232755    0.327096
#                   residual sugar        0.600000   4.229043    5.795707
#                   chlorides             0.009000   0.032462    0.044386
#                   free sulfur dioxide   2.000000  21.501784   34.654042
#                   total sulfur dioxide  9.000000  91.624516  136.180329
#                   density               0.002991   0.990569    0.993884
#                   pH                    0.151001   2.997500    3.184133
#                   sulphates             0.114126   0.362500    0.479923
#                   alcohol               1.230621   9.125000   10.457134
#                   quality               0.885639   4.500000    5.938955
#
#                                                75%     max
# Red Wines Stats   fixed acidity          10.875000  1599.0
#                   volatile acidity        0.875000  1599.0
#                   citric acid             0.565000  1599.0
#                   residual sugar          5.825000  1599.0
#                   chlorides               0.220250  1599.0
#                   free sulfur dioxide    33.750000  1599.0
#                   total sulfur dioxide  118.750000  1599.0
#                   density                 0.999299  1599.0
#                   pH                      3.552500  1599.0
#                   sulphates               1.047500  1599.0
#                   alcohol                12.050000  1599.0
#                   quality                 6.500000  1599.0
# White Wines Stats fixed acidity           9.025000  4898.0
#                   volatile acidity        0.515000  4898.0
#                   citric acid             0.707500  4898.0
#                   residual sugar         23.875000  4898.0
#                   chlorides               0.124000  4898.0
#                   free sulfur dioxide   106.750000  4898.0
#                   total sulfur dioxide  235.250000  4898.0
#                   density                 1.006820  4898.0
#                   pH                      3.415000  4898.0
#                   sulphates               0.682500  4898.0
#                   alcohol                12.100000  4898.0
#                   quality                 6.750000  4898.0

# %%
#Checking for Nulls in the data
all_wines.isnull().sum()
# Out:
# Red Wines Stats    fixed acidity           0
#                    volatile acidity        0
#                    citric acid             0
#                    residual sugar          0
#                    chlorides               0
#                    free sulfur dioxide     0
#                    total sulfur dioxide    0
#                    density                 0
#                    pH                      0
#                    sulphates               0
#                    alcohol                 0
#                    quality                 0
# White Wines Stats  fixed acidity           0
#                    volatile acidity        0
#                    citric acid             0
#                    residual sugar          0
#                    chlorides               0
#                    free sulfur dioxide     0
#                    total sulfur dioxide    0
#                    density                 0
#                    pH                      0
#                    sulphates               0
#                    alcohol                 0
#                    quality                 0
# dtype: int64

# %%
#Checking for duplicates
all_wines.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Check for objects or strings in the data if there are any
#string_col = all_wines.select_dtypes(include="object").columns
#all_wines[string_col].head()
